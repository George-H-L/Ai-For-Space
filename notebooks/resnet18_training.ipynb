# %% [markdown]
# # ResNet18 - Baseline Model
#
# **Owner:** Oliver
#
# ## Purpose
# Train a ResNet18 baseline on the preprocessed SAT-6 dataset. Establishes a benchmark for comparison against the main ResNet50 model.
#
# ## Steps
# 1. Load preprocessed splits from shared Drive
# 2. Initialise ResNet18 (pretrained or from scratch - TBC)
# 3. Define loss function and optimiser
# 4. Training loop with validation
# 5. Save model checkpoints to shared Drive
# 6. Log training/validation metrics per epoch
