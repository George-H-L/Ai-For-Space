# %% [markdown]
# # ResNet50 - Main Model
#
# **Owner:** Luca
#
# ## Purpose
# Train a ResNet50 as the main model on the preprocessed SAT-6 dataset, with hyperparameter tuning and learning rate scheduling.
#
# ## Steps
# 1. Load preprocessed splits from shared Drive
# 2. Initialise ResNet50 (pretrained or from scratch - TBC)
# 3. Define loss function, optimiser, and learning rate scheduler
# 4. Hyperparameter tuning
# 5. Training loop with validation
# 6. Save model checkpoints to shared Drive
# 7. Log training/validation metrics per epoch
